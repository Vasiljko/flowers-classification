# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/MyDrive/
# %cd Machine\ learning
# %cd flowers\ classification
# Out:
# /content/gdrive/MyDrive
# /content/gdrive/MyDrive/Machine learning
# /content/gdrive/MyDrive/Machine learning/flowers classification

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/gdrive/MyDrive/Machine learning/flowers classification/.git/

# %%
# !git remote add origin https://Vasiljko:californiaherewecome123@github.com/Vasiljko/flowers-classification.git
# !git remote -v
# Out:
# origin	https://Vasiljko:californiaherewecome123@github.com/Vasiljko/flowers-classification.git (fetch)
# origin	https://Vasiljko:californiaherewecome123@github.com/Vasiljko/flowers-classification.git (push)

# %%
# !git config --global user.email 'petarvasiljevic2001@gmail.com'
# !git config --global user.name 'Vasiljko'

# %%
# !git add .
# !git commit -m 'First commit'
# Out:
# [master (root-commit) 3ff4782] First commit
#  2 files changed, 2 insertions(+)
#  create mode 100644 flowers classification.ipynb
#  create mode 100644 git.ipynb

# %%
# !git push origin master
# Out:
# Counting objects: 4, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (4/4), done.
# Writing objects: 100% (4/4), 802.90 KiB | 9.79 MiB/s, done.
# Total 4 (delta 0), reused 0 (delta 0)
# remote: This repository moved. Please use the new location:
# remote:   https://github.com/Vasiljko/Flowers-classification.git
# To https://github.com/Vasiljko/flowers-classification.git
#  * [new branch]      master -> master
